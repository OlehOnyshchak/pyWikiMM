# %% [markdown]
# # Sample Dataset Collection
# ## Constant definition
#
# Fist of all, we need to specify some input parameters to our script. That is, input file with articles we want to download + parameters on how to download them.
#
# ### Input file
# It should be a file with article ids specified one per line. By article id here we mean last part of its url. That is, for the article with url https://en.wikipedia.org/wiki/The_Relapse on English Wikipedia, the id would be `The_Relapse`. Please note, that all article ids you specified in a file should be from the same wikipedia, i.e. either all English or all Ukrainian.
#
# ### Parameters
# Then you need to specify a variety of parameters to fine-tune the collection script. On high level, the script account to any previously downloaded information in order to inrease the performance. In other words,once you downloaded dataset from scratch, updating it will take very little time since most of the data will be already downloaded and unmodified since the last collection.
#
# In other words, since script leverages cache, you can interrupt and then restart the collection script at any time without the need to start everything from scratch. You can also specify, what specificly you want script to do 1) download missing articles and images from the input file 2) check that image metadata of already downloaded articles is up to date 3) force redownload off all images and/or image metadata and/or article text content. You can also execute the script from multiple notebooks/consoles with the same output directory in order to paralelise the collection process. That will signigicantly reduce the download time although you need to beware that not any (offset, limit) parameters overlap. We are planning to add support of multithreading later on, so now it's the only workaround. If you more details on parameters, please refere to documentation in correspoding python file.

# %%
import reader
import data_preprocessor
# Out:
# Using TensorFlow backend.

# %%
filename = 'input.tsv'
out_dir = './data_uk/' 
invalidate_caption_cache = True

query_params = reader.QueryParams(
    out_dir = out_dir,
    debug_info = True,
    offset = 0,
    limit = 5,
    invalidate_img_cache = False,
    invalidate_text_cache = False,
    invalidate_img_meta_cache = False,
    invalidate_oudated_img_meta_cache = True,
    only_update_cached_pages = False,
    language_code = 'uk',
)

# %% [markdown]
# ## Data Collection 1. Main Part
# In this section the script will do the major part of the work. That is, for each article specified, it will download its textual content, all its images and also some image metadata such as description parsed from Wikimedia Commons page. For details about what is being collected and what is the structure of the dataset, please refer to [Kaggle Dataset Page](https://www.kaggle.com/jacksoncrow/extended-wikipedia-multimodal-dataset)

# %%
# %%time
reader.query(filename=filename, params=query_params)
# Out:
# Downloading... offset=0, limit=3
#
# 0) data_uk/Атомний_підводний_човен_з_балістичними_ракетами
# Downloading text.json
# Updating image metadata
# Downloading image Akula_(Typhoon)_class_submarine_DD-ST-85-06625.jpg
# Downloading image Artist_rendering_of_a_Columbia-class_ballistic_missile_submarine,_2019_(190306-N-N0101-125).jpg
# Downloading image B05_SLBM.jpg
# Downloading image Commons-logo.svg
# Downloading image Delta-II_class_nuclear-powered_ballistic_missle_submarine_2.jpg
# Downloading image FA_gold_ukr.png
# Downloading image FS_Redoutable.jpg
# Downloading image Flag_of_France.svg
# Downloading image Flag_of_India.svg
# Downloading image Flag_of_North_Korea.svg
# Downloading image Flag_of_Russia.svg
# Downloading image Flag_of_the_People's_Republic_of_China.svg
# Downloading image Flag_of_the_Soviet_Union.svg
# Downloading image Flag_of_the_United_Kingdom.svg
# Downloading image Flag_of_the_United_States.svg
# Downloading image Jin_(Type_094)_Class_Ballistic_Missile_Submarine.JPG
# Downloading image Ohio-class_submarine_launches_Tomahawk_Cruise_missiles_(artist_concept).jpg
# Downloading image Plan_of_SSBN_616.png
# Downloading image Snle-snle-ng-svg.svg
# Downloading image Trident_Nuclear_Submarine_HMS_Victorious.jpg
# Downloading image UGM-133A_Trident_II_launch_in_June_2014.JPG
# Downloading image USS_George_Washington_(SSBN-598)_underway_at_sea,_circa_in_the_1970s.jpg
# Downloading image USS_Kentucky_(SSBN-737).jpg
# Downloading image USS_Ohio_(SSBN-726)_hatches.jpg
# Downloading image USS_Patrick_Henry_(SSBN-599)_launch_1959.jpg
# Downloading image USS_Patrick_Henry_(SSBN-599)_underway_with_crew_on_deck.jpg
# Downloading image Utmarkt_Guld.svg
# Downloading image АПЛ_Владимир_Мономах.jpg
# HTTP Error 404: Not Found
# Downloading image Ракетные_шахты.jpg
#
# 1) data_uk/Львів
# Downloading text.json
# WARNING: File 'Файл:Wikinews-logo.svg' contains missing revisions
# Updating image metadata
# Downloading image 12_Bandery_Street,_Lviv_(04).jpg
# Downloading image AndriiSadovyi.JPG
# Downloading image Boxed_East_arrow.svg
# Downloading image Cables_Lviv.jpg
# Downloading image Cartography_of_Europe.svg
# Downloading image City_locator_0.svg
# Downloading image Coat_of_Arms_of_Lviv_Oblast_SVG.svg
# Downloading image Coat_of_arms_of_Lviv.svg
# Downloading image Coat_of_arms_of_Ukraine.svg
# HTTP Error 404: Not Found
# Downloading image Coin_of_Ukraine_Lviv_A.jpg
# Downloading image Coin_of_Ukraine_Lviv_R.jpg
# Downloading image Commons-logo.svg
# Downloading image Compass_rose_pale-50x50.png
# Downloading image E14101.jpg
# Downloading image East.svg
# HTTP Error 404: Not Found
# Downloading image Electron_1179_(2).jpg
# Downloading image Europe_relief_laea_location_map.jpg
# Downloading image FA_gold_ukr.png
# Downloading image Flag_of_Albania.svg
# Downloading image Flag_of_Austria.svg
# Downloading image Flag_of_Belarus.svg
# Downloading image Flag_of_Bosnia_and_Herzegovina.svg
# Downloading image Flag_of_Bulgaria.svg
# Downloading image Flag_of_Canada_(Pantone).svg
# Downloading image Flag_of_Chechen_Republic_of_Ichkeria.svg
# Downloading image Flag_of_Croatia.svg
# Downloading image Flag_of_Denmark.svg
# Downloading image Flag_of_Finland.svg
# Downloading image Flag_of_France.svg
# Downloading image Flag_of_Georgia.svg
# Downloading image Flag_of_Germany.svg
# Downloading image Flag_of_Greece.svg
# Downloading image Flag_of_Hungary.svg
# Downloading image Flag_of_Ireland.svg
# Downloading image Flag_of_Israel.svg
# Downloading image Flag_of_Italy.svg
# Downloading image Flag_of_Latvia.svg
# Downloading image Flag_of_Lithuania.svg
# Downloading image Flag_of_Lviv.svg
# Downloading image Flag_of_Lviv_Oblast.png
# Downloading image Flag_of_Lviv_Oblast.svg
# Downloading image Flag_of_Moldova.svg
# Downloading image Flag_of_Norway.svg
# Downloading image Flag_of_Poland.svg
# Downloading image Flag_of_Portugal.svg
# Downloading image Flag_of_Romania.svg
# Downloading image Flag_of_Russia.svg
# Downloading image Flag_of_Serbia.svg
# Downloading image Flag_of_Spain.svg
# Downloading image Flag_of_Sweden.svg
# Downloading image Flag_of_Turkey.svg
# Downloading image Flag_of_Ukraine.svg
# Downloading image Flag_of_Uzbekistan.svg
# Downloading image Flag_of_the_Czech_Republic.svg
# Downloading image Flag_of_the_Netherlands.svg
# Downloading image Flag_of_the_People's_Republic_of_China.svg
# Downloading image Flag_of_the_United_Kingdom.svg
# Downloading image Gray_compass_rose.svg
# Downloading image Lesser_Coat_of_Arms_of_Ukraine.svg
# Downloading image Lev_Danylovich_of_Halych.PNG
# Downloading image Lviv-downtown(2).JPG
# Downloading image Lviv.Theatre.of.Opera.and.Ballet.jpg
# Downloading image Lviv_-_Arsenal_-_06.jpg
# Downloading image Lviv_City,_Ukraine,_Sentinel-2_satellite_image,_30-AUG-2017.jpg
# Downloading image Lviv_flag.svg
# HTTP Error 404: Not Found
# Downloading image Lwow_1.jpg
# Downloading image Lwów_-_Plac_Mickiewicza_02.JPG
# Downloading image Lwów_-_uniwersytet.JPG
# Downloading image North.svg
# Downloading image OptiWiktionary-logo.svg
# HTTP Error 404: Not Found
# Downloading image Park_Franko_in_Lviv.jpg
# Downloading image Red_pog.svg
# Downloading image Rough_360-degree_panoram_of_Lviv_center._-_panoramio.jpg
# Downloading image Searchtool.svg
# Downloading image SoftServeHQLviv.JPG
# Downloading image South.svg
# Downloading image Speaker_Icon.svg
# Downloading image Ukraine_adm_location_map_improved.svg
# Downloading image Utmarkt_Guld.svg
# Downloading image Wappen_Königreich_Galizien_&_Lodomerien.png
# Downloading image West.svg
# WARNING: File 'Файл:Wikinews-logo.svg' contains missing revisions
# Downloading image Wikinews-logo.svg
# Downloading image Wikiquote-logo.svg
# Downloading image Wikisource-logo.svg
# Downloading image Wikivoyage-Logo-v3-icon.svg
# Downloading image Wiktionary-logo.svg
# Downloading image ВП_День_батяра_2.jpg
# Downloading image Великий_герб.png
# HTTP Error 404: Not Found
# Downloading image Великий_герб_Львова.png
# Downloading image Вигляд_на_північну_частину_міста_з_гори_Лева.jpg
# Downloading image Ворота_в_парк_культуры_Львов.jpg
# Downloading image Вулиця_Митрополита_Андрея.jpg
# Downloading image Вулиця_Староєврейська.jpg
# Downloading image Завжди_вірні.jpg
# Downloading image Королевские_покои_Черная_каменица.jpg
# Downloading image Лвов_Галиција.jpg
# Downloading image Логотип_Львова.png
# Downloading image Львовский_лев_001.JPG
# Downloading image Львовский_пивзавод_3.jpg
# Downloading image Львівська_опер_-_нічна_панорама.jpg
# Downloading image Панельный_Сихов.jpg
# Downloading image Панорама_міста_Львова_з_вулиці_Лукаша,_1.jpg
# Downloading image Сихівський_район_Львова.jpg
# Downloading image Стрийський_парк_-_алея_у_верхній_частині.jpg
# Downloading image Театр_опери_та_балету_(Вигляд_з_фронту).jpg
# Downloading image Телефонний_автомат_Львів.jpg
# Downloading image Транспортне_кільце_Кільпарківська_-_Виговського_-_В._Великого.jpg
# Downloading image Церква,_всередині.jpg
# Downloading image King_Cross_Leopolis.jpg
# HTTP Error 404: Not Found
# Downloading image Національний_склад_населення_Львова_2001.png
# HTTP Error 404: Not Found
# Downloading image Початок_проспекту_Шевченка_(Львів).jpg
# HTTP Error 404: Not Found
# Downloading image Проспект_Свободи_старий.jpg
# HTTP Error 404: Not Found
# Downloading image Танго_смерті.jpg
# HTTP Error 404: Not Found
#
# 2) data_uk/Ервін_Шредінгер
# Downloading text.json
# Updating image metadata
# Downloading image 1000_Schilling_Erwin_Schrödinger_obverse.jpg
# Downloading image Albert_Einstein,_by_Doris_Ulmann.jpg
# Downloading image Atom_clipart_violet.svg
# Downloading image Boltzmann_age31.jpg
# Downloading image Civil_ensign_of_Austria-Hungary_(1869-1918).svg
# Downloading image Commons-logo.svg
# Downloading image Dublin_Institute_for_Advanced_Studies,_School_of_Theoretical_Physics.JPG
# Downloading image Eamon_de_Valera_c_1922-30.jpg
# Downloading image Erwin_Schrodinger2.jpg
# Downloading image Erwin_Schrodinger_at_U_Vienna.JPG
# Downloading image Erwin_Schrödinger_(1933).jpg
# Downloading image Erwin_Schrödinger_signature.svg
# Downloading image FA_gold_ukr.png
# Downloading image Flag_of_Austria-Hungary_(1869-1918).svg
# Downloading image Flag_of_Austria.svg
# Downloading image Flag_of_German_Reich_(1935–1945).svg
# HTTP Error 404: Not Found
# Downloading image Flag_of_Germany.svg
# Downloading image Flag_of_Germany_(1935–1945).svg
# Downloading image Flag_of_Ireland.svg
# Downloading image Franz-Serafin_Exner.JPG
# Downloading image GuentherZ_2007-02-22_2704_Wr_Akad_Gym_Erwin_Schroedinger.jpg
# Downloading image Hasenoehrl.jpg
# Downloading image Heisenberg_10.jpg
# Downloading image Magdalen_College_in_Oxford_-_geograph.org.uk_-_1419192.jpg
# Downloading image Max_Delbruck.jpg
# Downloading image Nobel_prize_medal.svg
# Downloading image Rutherford_atom.svg
# Downloading image Schroedinger_alpbach.jpg
# Downloading image Searchtool.svg
# Downloading image Solvay_conference_1927.jpg
# Downloading image Utmarkt_Guld.svg
# Downloading image Wikiquote-logo.svg
# Downloading image Wilhelm_Wien.jpg
#
# Downloaded 175 images, where 0 of them unavailable from commons
# CPU times: user 8.71 s, sys: 382 ms, total: 9.09 s
# Wall time: 4min 25s

# %% [markdown]
# ## Data Preprocessing 1. Removing images not available on Commons
# Before proceeding to costly operation of additional image caption downloading&parsing, we will first remove all images not available from Wikimida Commons dataset. Usually, those are the images which were licensed only for usage in specific article and are not publicly available. They constitute around 5-7% of images, so for now we just removing them but later we might investigate licensing condition and, if allowed, include them to the dataset.

# %%
data_preprocessor.filter_img_metadata(
    data_path=query_params.out_dir,
    offset=query_params.offset,
    limit=query_params.limit, 
    debug_info=query_params.debug_info,
    field_to_remove='on_commons',
    predicate=lambda x: x['on_commons']
)
# Out:
# 0 ./data_uk/Львів
# 1 ./data_uk/Ервін_Шредінгер
# 2 ./data_uk/Атомний_підводний_човен_з_балістичними_ракетами

# %% [markdown]
# ## Data Collection 2. Image Captions
# This part was separated from the main pipeline because it's very time consuming and we need to use it carefully and only when it's required. This function is firstly trying to parse as many caption as possible with a fast but unreliable approach. After that, it gathers all remaining captions with time-consuming approach, which is to download html preview-pages for each image in the article. Futhermore, it's dynamicly generated content by javascript, thus we need to execute that generating code internally, when loading the page.
#
# Again, if you need further details, please refer to [Kaggle Dataset Page](https://www.kaggle.com/jacksoncrow/extended-wikipedia-multimodal-dataset)

# %%
# %%time
reader.query_img_captions(
    filename=filename,
    out_dir=query_params.out_dir,
    offset=query_params.offset,
    limit=query_params.limit,
    language_code=query_params.language_code,
    invalidate_cache=invalidate_caption_cache,
    debug_info=query_params.debug_info,
)
# Out:
# Querying available captions with fast approach
#
# 0 data_uk/Атомний_підводний_човен_з_балістичними_ракетами
# WARNING: Meta for page data_uk/Атомний_підводний_човен_з_балістичними_ракетами is missing the image Файл:АПЛ_"Владимир_Мономах".jpg. Either was removed intentionally or cache is outdated
# 1 data_uk/Львів
# WARNING: Cannot parse url ex.php?title=Файл:Проспект_Свободи_старий.jpg&filetimestamp=20100531065925
# WARNING: Cannot parse url ex.php?title=Файл:Початок_проспекту_Шевченка_(Львів).jpg&filetimestamp=20100526203351
# WARNING: Cannot parse url ex.php?title=Файл:Танго_смерті.jpg&filetimestamp=20100225144245
# WARNING: Cannot parse url ex.php?title=Файл:Національний_склад_населення_Львова_2001.png&filetimestamp=20100615131505
# WARNING: Cannot parse url ex.php?title=Файл:King_Cross_Leopolis.jpg&filetimestamp=20100512185922
# 2 data_uk/Ервін_Шредінгер
#
# Querying remaining unparsed caption with time-consuming approach
#
#
# 0) data_uk/Атомний_підводний_човен_з_балістичними_ракетами
# Skipping cached caption Akula_(Typhoon)_class_submarine_DD-ST-85-06625.jpg
# Skipping cached caption Artist_rendering_of_a_Columbia-class_ballistic_missile_submarine,_2019_(190306-N-N0101-125).jpg
# Skipping cached caption B05_SLBM.jpg
# Skipping known icon Commons-logo.svg
# Skipping cached caption Delta-II_class_nuclear-powered_ballistic_missle_submarine_2.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:FA_gold_ukr.png
# RETRY 0  |||  FA_gold_ukr.png
# RETRY 1  |||  FA_gold_ukr.png
# RETRY 2  |||  FA_gold_ukr.png
# RETRY 3  |||  FA_gold_ukr.png
# RETRY 4  |||  FA_gold_ukr.png
# Skipping cached caption FS_Redoutable.jpg
# Skipping known icon Flag_of_France.svg
# Skipping known icon Flag_of_India.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:Flag_of_North_Korea.svg
# Skipping known icon Flag_of_Russia.svg
# Skipping known icon Flag_of_the_People's_Republic_of_China.svg
# Skipping known icon Flag_of_the_Soviet_Union.svg
# Skipping known icon Flag_of_the_United_Kingdom.svg
# Skipping known icon Flag_of_the_United_States.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:Jin_(Type_094)_Class_Ballistic_Missile_Submarine.JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:Ohio-class_submarine_launches_Tomahawk_Cruise_missiles_(artist_concept).jpg
# Skipping cached caption Plan_of_SSBN_616.png
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:Snle-snle-ng-svg.svg
# Skipping cached caption Trident_Nuclear_Submarine_HMS_Victorious.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:UGM-133A_Trident_II_launch_in_June_2014.JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:USS_George_Washington_(SSBN-598)_underway_at_sea,_circa_in_the_1970s.jpg
# Skipping cached caption USS_Kentucky_(SSBN-737).jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:USS_Ohio_(SSBN-726)_hatches.jpg
# Skipping cached caption USS_Patrick_Henry_(SSBN-599)_launch_1959.jpg
# Skipping cached caption USS_Patrick_Henry_(SSBN-599)_underway_with_crew_on_deck.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:Utmarkt_Guld.svg
# RETRY 0  |||  Utmarkt_Guld.svg
# RETRY 1  |||  Utmarkt_Guld.svg
# RETRY 2  |||  Utmarkt_Guld.svg
# RETRY 3  |||  Utmarkt_Guld.svg
# RETRY 4  |||  Utmarkt_Guld.svg
# WARNING: outdated page Атомний_підводний_човен_з_балістичними_ракетами, missing image АПЛ_"Владимир_Мономах".jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Атомний_підводний_човен_з_балістичними_ракетами#/media/Файл:Ракетные_шахты.jpg
#
# 1) data_uk/Львів
# Skipping cached caption 12_Bandery_Street,_Lviv_(04).jpg
# Skipping cached caption AndriiSadovyi.JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Boxed_East_arrow.svg
# RETRY 0  |||  Boxed_East_arrow.svg
# RETRY 1  |||  Boxed_East_arrow.svg
# RETRY 2  |||  Boxed_East_arrow.svg
# RETRY 3  |||  Boxed_East_arrow.svg
# RETRY 4  |||  Boxed_East_arrow.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Cables_Lviv.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Cartography_of_Europe.svg
# RETRY 0  |||  Cartography_of_Europe.svg
# RETRY 1  |||  Cartography_of_Europe.svg
# RETRY 2  |||  Cartography_of_Europe.svg
# RETRY 3  |||  Cartography_of_Europe.svg
# RETRY 4  |||  Cartography_of_Europe.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:City_locator_0.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Coat_of_Arms_of_Lviv_Oblast_SVG.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Coat_of_arms_of_Lviv.svg
# WARNING: outdated page Львів, missing image Coat_of_arms_of_Ukraine.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Coin_of_Ukraine_Lviv_A.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Coin_of_Ukraine_Lviv_R.jpg
# Skipping known icon Commons-logo.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Compass_rose_pale-50x50.png
# RETRY 0  |||  Compass_rose_pale-50x50.png
# RETRY 1  |||  Compass_rose_pale-50x50.png
# RETRY 2  |||  Compass_rose_pale-50x50.png
# RETRY 3  |||  Compass_rose_pale-50x50.png
# RETRY 4  |||  Compass_rose_pale-50x50.png
# Skipping cached caption E14101.jpg
# WARNING: outdated page Львів, missing image East.svg
# Skipping cached caption Electron_1179_(2).jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Europe_relief_laea_location_map.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:FA_gold_ukr.png
# RETRY 0  |||  FA_gold_ukr.png
# RETRY 1  |||  FA_gold_ukr.png
# RETRY 2  |||  FA_gold_ukr.png
# RETRY 3  |||  FA_gold_ukr.png
# RETRY 4  |||  FA_gold_ukr.png
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Albania.svg
# Skipping known icon Flag_of_Austria.svg
# Skipping known icon Flag_of_Belarus.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Bosnia_and_Herzegovina.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Bulgaria.svg
# Skipping known icon Flag_of_Canada_(Pantone).svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Chechen_Republic_of_Ichkeria.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Croatia.svg
# Skipping known icon Flag_of_Denmark.svg
# Skipping known icon Flag_of_Finland.svg
# Skipping known icon Flag_of_France.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Georgia.svg
# Skipping known icon Flag_of_Germany.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Greece.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Hungary.svg
# RETRY 0  |||  Flag_of_Hungary.svg
# Skipping known icon Flag_of_Ireland.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Israel.svg
# Skipping known icon Flag_of_Italy.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Latvia.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Lithuania.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Lviv.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Lviv_Oblast.png
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Lviv_Oblast.svg
# RETRY 0  |||  Flag_of_Lviv_Oblast.svg
# RETRY 1  |||  Flag_of_Lviv_Oblast.svg
# RETRY 2  |||  Flag_of_Lviv_Oblast.svg
# RETRY 3  |||  Flag_of_Lviv_Oblast.svg
# RETRY 4  |||  Flag_of_Lviv_Oblast.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Moldova.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Norway.svg
# Skipping known icon Flag_of_Poland.svg
# Skipping known icon Flag_of_Portugal.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Romania.svg
# Skipping known icon Flag_of_Russia.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Serbia.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Spain.svg
# Skipping known icon Flag_of_Sweden.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Turkey.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Ukraine.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_Uzbekistan.svg
# Skipping known icon Flag_of_the_Czech_Republic.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Flag_of_the_Netherlands.svg
# Skipping known icon Flag_of_the_People's_Republic_of_China.svg
# Skipping known icon Flag_of_the_United_Kingdom.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Gray_compass_rose.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Lesser_Coat_of_Arms_of_Ukraine.svg
# Skipping cached caption Lev_Danylovich_of_Halych.PNG
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Lviv-downtown(2).JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Lviv.Theatre.of.Opera.and.Ballet.jpg
# Skipping cached caption Lviv_-_Arsenal_-_06.jpg
# Skipping cached caption Lviv_City,_Ukraine,_Sentinel-2_satellite_image,_30-AUG-2017.jpg
# WARNING: outdated page Львів, missing image Lviv_flag.svg
# Skipping cached caption Lwow_1.jpg
# Skipping cached caption Lwów_-_Plac_Mickiewicza_02.JPG
# Skipping cached caption Lwów_-_uniwersytet.JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:North.svg
# RETRY 0  |||  North.svg
# RETRY 1  |||  North.svg
# RETRY 2  |||  North.svg
# RETRY 3  |||  North.svg
# RETRY 4  |||  North.svg
# WARNING: outdated page Львів, missing image OptiWiktionary-logo.svg
# Skipping cached caption Park_Franko_in_Lviv.jpg
# Skipping known icon Red_pog.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Rough_360-degree_panoram_of_Lviv_center._-_panoramio.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Searchtool.svg
# RETRY 0  |||  Searchtool.svg
# RETRY 1  |||  Searchtool.svg
# RETRY 2  |||  Searchtool.svg
# RETRY 3  |||  Searchtool.svg
# RETRY 4  |||  Searchtool.svg
# Skipping cached caption SoftServeHQLviv.JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:South.svg
# RETRY 0  |||  South.svg
# RETRY 1  |||  South.svg
# RETRY 2  |||  South.svg
# RETRY 3  |||  South.svg
# RETRY 4  |||  South.svg
# Skipping known icon Speaker_Icon.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Ukraine_adm_location_map_improved.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Utmarkt_Guld.svg
# RETRY 0  |||  Utmarkt_Guld.svg
# RETRY 1  |||  Utmarkt_Guld.svg
# RETRY 2  |||  Utmarkt_Guld.svg
# RETRY 3  |||  Utmarkt_Guld.svg
# RETRY 4  |||  Utmarkt_Guld.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Wappen_Königreich_Galizien_&_Lodomerien.png
# RETRY 0  |||  Wappen_Königreich_Galizien_&_Lodomerien.png
# RETRY 1  |||  Wappen_Königreich_Galizien_&_Lodomerien.png
# RETRY 2  |||  Wappen_Königreich_Galizien_&_Lodomerien.png
# RETRY 3  |||  Wappen_Königreich_Galizien_&_Lodomerien.png
# RETRY 4  |||  Wappen_Königreich_Galizien_&_Lodomerien.png
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:West.svg
# RETRY 0  |||  West.svg
# RETRY 1  |||  West.svg
# RETRY 2  |||  West.svg
# RETRY 3  |||  West.svg
# RETRY 4  |||  West.svg
# Skipping known icon Wikinews-logo.svg
# Skipping known icon Wikiquote-logo.svg
# Skipping known icon Wikisource-logo.svg
# Skipping known icon Wikivoyage-Logo-v3-icon.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Wiktionary-logo.svg
# WARNING: File 'Файл:Wikinews-logo.svg' contains missing revisions
# RETRY 0  |||  Wiktionary-logo.svg
# RETRY 1  |||  Wiktionary-logo.svg
# RETRY 2  |||  Wiktionary-logo.svg
# RETRY 3  |||  Wiktionary-logo.svg
# RETRY 4  |||  Wiktionary-logo.svg
# Skipping cached caption ВП_День_батяра_2.jpg
# WARNING: outdated page Львів, missing image Великий_герб.png
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Великий_герб_Львова.png
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Вигляд_на_північну_частину_міста_з_гори_Лева.jpg
# Skipping cached caption Ворота_в_парк_культуры_Львов.jpg
# Skipping cached caption Вулиця_Митрополита_Андрея.jpg
# Skipping cached caption Вулиця_Староєврейська.jpg
# Skipping cached caption Завжди_вірні.jpg
# Skipping cached caption Королевские_покои_Черная_каменица.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Лвов_Галиција.jpg
# Skipping cached caption Логотип_Львова.png
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Львовский_лев_001.JPG
# Skipping cached caption Львовский_пивзавод_3.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Львівська_опер_-_нічна_панорама.jpg
# Skipping cached caption Панельный_Сихов.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Панорама_міста_Львова_з_вулиці_Лукаша,_1.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Сихівський_район_Львова.jpg
# Skipping cached caption Стрийський_парк_-_алея_у_верхній_частині.jpg
# Skipping cached caption Театр_опери_та_балету_(Вигляд_з_фронту).jpg
# Skipping cached caption Телефонний_автомат_Львів.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Львів#/media/Файл:Транспортне_кільце_Кільпарківська_-_Виговського_-_В._Великого.jpg
# Skipping cached caption Церква,_всередині.jpg
# WARNING: outdated page Львів, missing image King_Cross_Leopolis.jpg
# WARNING: outdated page Львів, missing image Національний_склад_населення_Львова_2001.png
# WARNING: outdated page Львів, missing image Початок_проспекту_Шевченка_(Львів).jpg
# WARNING: outdated page Львів, missing image Проспект_Свободи_старий.jpg
# WARNING: outdated page Львів, missing image Танго_смерті.jpg
#
# 2) data_uk/Ервін_Шредінгер
# Skipping cached caption 1000_Schilling_Erwin_Schrödinger_obverse.jpg
# Skipping cached caption Albert_Einstein,_by_Doris_Ulmann.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Atom_clipart_violet.svg
# RETRY 0  |||  Atom_clipart_violet.svg
# RETRY 1  |||  Atom_clipart_violet.svg
# RETRY 2  |||  Atom_clipart_violet.svg
# RETRY 3  |||  Atom_clipart_violet.svg
# RETRY 4  |||  Atom_clipart_violet.svg
# Skipping cached caption Boltzmann_age31.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Civil_ensign_of_Austria-Hungary_(1869-1918).svg
# Skipping known icon Commons-logo.svg
# Skipping cached caption Dublin_Institute_for_Advanced_Studies,_School_of_Theoretical_Physics.JPG
# Skipping cached caption Eamon_de_Valera_c_1922-30.jpg
# Skipping cached caption Erwin_Schrodinger2.jpg
# Skipping cached caption Erwin_Schrodinger_at_U_Vienna.JPG
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Erwin_Schrödinger_(1933).jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Erwin_Schrödinger_signature.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:FA_gold_ukr.png
# RETRY 0  |||  FA_gold_ukr.png
# RETRY 1  |||  FA_gold_ukr.png
# RETRY 2  |||  FA_gold_ukr.png
# RETRY 3  |||  FA_gold_ukr.png
# RETRY 4  |||  FA_gold_ukr.png
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Flag_of_Austria-Hungary_(1869-1918).svg
# Skipping known icon Flag_of_Austria.svg
# WARNING: outdated page Ервін_Шредінгер, missing image Flag_of_German_Reich_(1935–1945).svg
# Skipping known icon Flag_of_Germany.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Flag_of_Germany_(1935–1945).svg
# Skipping known icon Flag_of_Ireland.svg
# Skipping cached caption Franz-Serafin_Exner.JPG
# Skipping cached caption GuentherZ_2007-02-22_2704_Wr_Akad_Gym_Erwin_Schroedinger.jpg
# Skipping cached caption Hasenoehrl.jpg
# Skipping cached caption Heisenberg_10.jpg
# Skipping cached caption Magdalen_College_in_Oxford_-_geograph.org.uk_-_1419192.jpg
# Skipping cached caption Max_Delbruck.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Nobel_prize_medal.svg
# RETRY 0  |||  Nobel_prize_medal.svg
# RETRY 1  |||  Nobel_prize_medal.svg
# RETRY 2  |||  Nobel_prize_medal.svg
# RETRY 3  |||  Nobel_prize_medal.svg
# RETRY 4  |||  Nobel_prize_medal.svg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Rutherford_atom.svg
# RETRY 0  |||  Rutherford_atom.svg
# RETRY 1  |||  Rutherford_atom.svg
# RETRY 2  |||  Rutherford_atom.svg
# RETRY 3  |||  Rutherford_atom.svg
# RETRY 4  |||  Rutherford_atom.svg
# Skipping cached caption Schroedinger_alpbach.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Searchtool.svg
# RETRY 0  |||  Searchtool.svg
# RETRY 1  |||  Searchtool.svg
# RETRY 2  |||  Searchtool.svg
# RETRY 3  |||  Searchtool.svg
# RETRY 4  |||  Searchtool.svg
# Skipping cached caption Solvay_conference_1927.jpg
# Downloading captions for https://uk.wikipedia.org/wiki/Ервін_Шредінгер#/media/Файл:Utmarkt_Guld.svg
# RETRY 0  |||  Utmarkt_Guld.svg
# RETRY 1  |||  Utmarkt_Guld.svg
# RETRY 2  |||  Utmarkt_Guld.svg
# RETRY 3  |||  Utmarkt_Guld.svg
# RETRY 4  |||  Utmarkt_Guld.svg
# Skipping known icon Wikiquote-logo.svg
# Skipping cached caption Wilhelm_Wien.jpg
# {'Flag_of_Belarus.svg', 'Commons-logo.svg', "Flag_of_the_People's_Republic_of_China.svg", 'Flag_of_India.svg', 'Flag_of_Italy.svg', 'Nobel_prize_medal.svg', 'Boxed_East_arrow.svg', 'Wiktionary-logo.svg', 'Flag_of_Austria.svg', 'Flag_of_Portugal.svg', 'Searchtool.svg', 'Flag_of_the_United_Kingdom.svg', 'Red_pog.svg', 'Flag_of_France.svg', 'Wikinews-logo.svg', 'Flag_of_Lviv_Oblast.svg', 'Rutherford_atom.svg', 'South.svg', 'Utmarkt_Guld.svg', 'Atom_clipart_violet.svg', 'FA_gold_ukr.png', 'North.svg', 'Flag_of_Denmark.svg', 'Wikiquote-logo.svg', 'Wikisource-logo.svg', 'Flag_of_Russia.svg', 'Wappen_Königreich_Galizien_&_Lodomerien.png', 'Flag_of_the_Soviet_Union.svg', 'West.svg', 'Wikivoyage-Logo-v3-icon.svg', 'Cartography_of_Europe.svg', 'Flag_of_Canada_(Pantone).svg', 'Flag_of_Ireland.svg', 'Flag_of_Sweden.svg', 'Flag_of_Finland.svg', 'Flag_of_the_Czech_Republic.svg', 'Compass_rose_pale-50x50.png', 'Speaker_Icon.svg', 'Flag_of_Poland.svg', 'Flag_of_the_United_States.svg', 'Flag_of_Germany.svg'}
# CPU times: user 1.98 s, sys: 167 ms, total: 2.15 s
# Wall time: 3min 58s

# %% [markdown]
# ## Data Preproccesing 2. Removing icons
# Most commontly, icons is an auxiliary image which represents particular template or category. It's not directly linked to the content described in the article, so we remove them as noisy data. We identify icons within other images under the assumption that user cannot load preview for icons on Wiki page. That is, if you click on icon from your browser, it will either do nothing or will redirect you to another page. While for images used in the article, it will load a full-screen preview. And while this approach will not work in 100% of cases, currently we identified it as the most reliable approach to perform icon identification.
#
# So in this part, we remove all images which were identified as icons.

# %%
data_preprocessor.filter_img_metadata(
    data_path=query_params.out_dir,
    offset=query_params.offset,
    limit=query_params.limit, 
    debug_info=query_params.debug_info,
    field_to_remove='is_icon',
    predicate=lambda x: not x['is_icon']
)
# Out:
# 0 ./data_uk/Львів
# 1 ./data_uk/Ервін_Шредінгер
# 2 ./data_uk/Атомний_підводний_човен_з_балістичними_ракетами

# %%
1080000/ 2048
# Out:
# 527.34375

# %% [markdown]
# ## Data Preprocessing 3. Generating visual features
# Lastly, in order to make usage of dataset more time and space efficient, we will calculate visual features for every image and record them in dataset. By doing so, we will
# * save space: raw image of shape (600,600,3) occupies 500 times more space then a visual feature vector with 2048 elements, while providing the same amount of useful information
# * save time: calculating those features from scratch is very time-consuming process. So by having them saved in the dataset, every user of the dataset will not need to calculate them as well
#
# For feature generation we used `ResNet152` pretrained on `ImageNet` dataset. And features themselfs are the output of the lash hidden fully-connecte layer of the network, which has the shape of (19, 24, 2048), and then transform it to a vector of 2048 items by max-pooling operation. That vector of 2048 items will serve as our feature vector for each image.
#
# And while we understand that this representation might not be ideal in your scenario, it seems to be useful in varaious situation. If you need to calculate features in other way, please just modify this last step.

# %%
# %%time
data_preprocessor.generate_visual_features(
    data_path=query_params.out_dir,
    offset=query_params.offset,
    limit=query_params.limit,
    debug_info=query_params.debug_info,
)
# Out:
# 0 ./data_uk/Львів
# 1 ./data_uk/Ервін_Шредінгер
# 2 ./data_uk/Атомний_підводний_човен_з_балістичними_ракетами
# CPU times: user 15min 16s, sys: 8.48 s, total: 15min 24s
# Wall time: 2min 38s

# %% [markdown]
# ## Dataset Examinations
# ### text.json file
# This file contains article textual information, such as: content of the article in wikitext and html format, article title, id, and url. For further details, please refer to [Kaggle Dataset Page](https://www.kaggle.com/jacksoncrow/extended-wikipedia-multimodal-dataset)

# %%
import json
import pprint

text_path = out_dir + "Атомний_підводний_човен_з_балістичними_ракетами" + "/text.json"
pp = pprint.PrettyPrinter(indent=2)
data = None
with open(text_path) as json_file:
    data = json.loads(json.load(json_file))

print_data = data
print_data['wikitext'] = print_data['wikitext'][:5000]
print_data['html'] = print_data['html'][:5000]

pp.pprint(print_data)
# Out:
# { 'html': '\n'
#           '<!DOCTYPE html>\n'
#           '<html class="client-nojs" lang="uk" dir="ltr">\n'
#           '<head>\n'
#           '<meta charset="UTF-8"/>\n'
#           '<title>Атомний підводний човен з балістичними ракетами — '
#           'Вікіпедія</title>\n'
#           '<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xa0'
#           '\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","січень","лютий","березень","квітень","травень","червень","липень","серпень","вересень","жовтень","листопад","грудень"],"wgRequestId":"Xnw@nQpAMMMAAXiJqyYAAACW","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Атомний_підводний_човен_з_балістичними_ракетами","wgTitle":"Атомний '
#           'підводний човен з балістичними '
#           'ракетами","wgCurRevisionId":27509404,"wgRevisionId":27509404,"wgArticleId":2983826,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[\n'
#           '"Шаблон:Webarchive:посилання на Wayback Machine","Сторінки, що '
#           'використовують магічні посилання ISBN","Вибрані статті","Атомні '
#           'підводні човни з балістичними ракетами","Ядерна стратегія","Ракетна '
#           'зброя"],"wgPageContentLanguage":"uk","wgPageContentModel":"wikitext","wgRelevantPageName":"Атомний_підводний_човен_з_балістичними_ракетами","wgRelevantArticleId":2983826,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{"accuracy":{"levels":3,"quality":2,"pristine":4}}},"wgStableRevisionId":27509404,"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"uk","pageLanguageDir":"ltr",\n'
#           '"pageVariantFallbacks":"uk"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"українська","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q683570","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.showContributorContent":"ready","ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.flaggedRevs.icons":"ready","oojs-ui-core.styles":"ready","oojs-ui.styles.indicators":"ready","mediawiki.widgets.styles":"ready","oojs-ui-core.icons":"ready","mediawiki.page.gallery.styles":"ready","ext.cite.styles":"ready","jquery.tablesorter.styles":"ready","mediawiki.toc.styles":"ready","skins.vector.styles.legacy":"ready","wikibase.client.init":"ready","ext.flaggedRevs.basic":"ready",\n'
#           '"ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","skins.vector.js","mediawiki.page.ready","jquery.tablesorter","mediawiki.toc","ext.flaggedRevs.advanced","ext.gadget.collapserefs","ext.gadget.ReferenceTooltips","ext.gadget.edittop","ext.gadget.new-section","ext.gadget.newTopicOnTop","ext.gadget.MonobookToolbarStandard","ext.gadget.ProtectionIndicator","ext.gadget.Statistics","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>\n'
#           '<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1tqge",function($,jQuery,require,module){/*@nomin*/mw.user.options.set({"variant":"uk"});\n'
#           '});mw.loader.implement("user.tokens@tffin",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});\n'
#           '});});</script>\n'
#           '<link rel="stylesheet" '
#           'href="/w/load.php?lang=uk&amp;modules=ext.cite.styles%7Cext.flaggedRevs.basic%2Cicons%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.page.gallery.styles%7Cmediawiki.toc.styles%7Cmediawiki.widgets.styles%7Coojs-ui-core.icons%2Cstyles%7Coojs-ui.styles.indicators%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n'
#           '<script async="" '
#           'src="/w/load.php?lang=uk&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n'
#           '<meta name="ResourceLoaderDynamicStyles" content=""/>\n'
#           '<link rel="stylesheet" '
#           'href="/w/load.php?lang=uk&amp;modules=ext.gadget.showContributorContent&amp;only=styles&amp;skin=vector"/>\n'
#           '<link rel="stylesheet" '
#           'href="/w/load.php?lang=uk&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n'
#           '<meta name="generator" content="MediaWiki 1.35.0-wmf.24"/>\n'
#           '<meta name="referrer" content="origin"/>\n'
#           '<meta name="referrer" content="origin-when-crossorigin"/>\n'
#           '<meta name="referrer',
#   'id': 2983826,
#   'title': 'Атомний підводний човен з балістичними ракетами',
#   'url': 'https://uk.wikipedia.org/wiki/%D0%90%D1%82%D0%BE%D0%BC%D0%BD%D0%B8%D0%B9_%D0%BF%D1%96%D0%B4%D0%B2%D0%BE%D0%B4%D0%BD%D0%B8%D0%B9_%D1%87%D0%BE%D0%B2%D0%B5%D0%BD_%D0%B7_%D0%B1%D0%B0%D0%BB%D1%96%D1%81%D1%82%D0%B8%D1%87%D0%BD%D0%B8%D0%BC%D0%B8_%D1%80%D0%B0%D0%BA%D0%B5%D1%82%D0%B0%D0%BC%D0%B8',
#   'wikitext': '{| align="right" style="background:#f8f9fa; border:1px solid '
#               '#c8ccd1; font-size:90%; margin-left:1em" cellspacing=0 '
#               'cellpadding=0\n'
#               '|-\n'
#               '|<gallery perrow="1" widths="280" heights="180">\n'
#               'Файл:Ohio-class submarine launches Tomahawk Cruise missiles '
#               '(artist concept).jpg|Запуск ракет з ПЧАРБ типу [[Підводні човни '
#               "типу «Огайо»|«Огайо»]] ([[Комп'ютерна "
#               '3D-графіка|3D-зображення]])\n'
#               'Файл:UGM-133A Trident II launch in June 2014.JPG|Пуск '
#               '[[Трайдент (ракета)|БРПЧ «Трайдент-II»]] ПЧАРБ [[USS West '
#               'Virginia (SSBN-736)|«Західна Вірджинія»]] ВМС США, 2 червня '
#               '2014\n'
#               'Файл:USS George Washington (SSBN-598) underway at sea, circa in '
#               'the 1970s.jpg|ПЧАРБ [[USS George Washington (SSBN-598)|«Джордж '
#               'Вашингтон»]] ВМС США — перший представник морської складової '
#               '[[Ядерна тріада|ядерної тріади]]. Увійшов у склад флоту 9 '
#               'червня 1959\n'
#               '</gallery>\n'
#               '|-\n'
#               '|<center></center>\n'
#               '|}\n'
#               "'''Атомний підводний човен з балістичними ракетами''' "
#               "([[Абревіатура|абр.]] '''''ПЧАРБ'''&nbsp;— '''П'''ідводний "
#               "'''Ч'''овен '''А'''томний з '''Р'''акетами "
#               "'''Б'''алістичними'', "
#               '{{lang-en|{{Comment|SSBN|Submarine-launched ballistic '
#               'missile}}}})&nbsp;— клас [[Атомний підводний човен|атомних '
#               'підводних човнів]], основним озброєнням яких є [[Балістичні '
#               'ракети підводних човнів|балістичні ракети стратегічного '
#               'призначення «корабель-земля»]] (БРПЧ). Призначені для ураження '
#               "важливих об'єктів&nbsp;— [[Адміністративний "
#               'центр|адміністративних]], [[Промислова '
#               'агломерація|економічних]] і військово-промислових центрів, '
#               '[[Військово-морська база|військово-морських баз]], [[порт]]ів '
#               'та інших стратегічних цілей. Мають [[Ядерний реактор|ядерну '
#               'енергетичну установку]] і [[Балістичні ракети підводних '
#               'човнів|балістичні ракети морського базування]] великої '
#               '(міжконтинентальної) дальності, які призначені для завдання '
#               'ракетно-ядерних [[Удар (військова справа)|ударів]] по території '
#               'противника, здійснюючи плавання в будь-яких районах [[Світовий '
#               'океан|світового океану]], зокрема з [[Арктика|арктичних '
#               'районів]], приховано, не спливаючи в надводне '
#               'положення{{sfn|Военный энциклопедический словарь|1983|місце=с. '
#               "322. ''Подводная лодка''}}.\n"
#               '\n'
#               'Морська складова [[Ядерна тріада|стратегічної ядерної тріади]]. '
#               'Виникли як клас у 1950—1960-х роках із появою ракетної і '
#               'ядерної техніки. Бойові можливості ПЧАРБ постійно зростали з '
#               'розробкою досконаліших ракетно-ядерних комплексів&nbsp;— '
#               'збільшувалися масогабаритні характеристики БРПЧ, дальність їх '
#               'польоту, ефективність ураження цілей. [[Бойова частина|Головні '
#               'частини]] ракет із [[Ядерна зброя|ядерним зарядом]] потужністю '
#               'до 100—350 кт, моноблочні на перших підводних ракетоносцях, на '
#               'сучасних ПЧАРБ стали роздільними, з 3—10 бойовими блоками '
#               'індивідуального наведення, дальність стрільби перевищила 11 '
#               'тисяч кілометрів, точність попадання досягла [[Кругове ймовірне '
#               'відхилення|КІВ]] 90—120&nbsp;м{{sfn|Доценко В.|2003|місце=Флоты '
#               'XX века}}.\n'
#               '\n'
#               'Застосовуються як самостійно, так і в складі угруповань '
#               'підводних човнів та різнорідних сил флоту. Крім основного '
#               'озброєння,&nbsp;— [[Балістичні ракети підводних '
#               'човнів|стратегічних балістичних ракет]],&nbsp;— мають на '
#               'озброєнні ефективні засоби боротьби з [[Протичовнова '
#               "оборона|протичовновими силами]], засоби спостереження, зв'язку "
#               'й управління, навігації, запобігання несанкціонованому доступу '
#               'до ракетно-ядерної зброї, інші радіоелектронні, обчислювальні і '
#               'технічні засоби{{sfn|Военный энциклопедический '
#               "словарь|1983|місце=с. 322. ''Подводная лодка''}}.\n"
#               '\n'
#               'Сьогодні в усьому світі експлуатується понад три десятки ПЧАРБ. '
#               'Флоти усіх держав, що розпочали експлуатацію атомних підводних '
#               'човнів з міжконтинентальними балістичними ракетами під час '
#               '[[Холодна війна|«холодної війни»]], мають ці системи озброєння '
#               'й досі. Це разом з [[Військово-морські сили США|ВМС США]] та '
#               '[[Військово-морський флот Російської Федерації|ВМФ '
#               'Росії]]&nbsp;— наступника [[Військово-морський флот СРСР|ВМФ '
#               'СРСР]], є [[Військово-морські сили Великої Британії|ВМС Великої '
#               'Британії]], [[Військово-морські сили Франції|Франції]] і '
#               '[[Військово-морські сили Китайської Народної '
#               'Республіки|Китаю]]. У [[2016]] році поставила на озброєння свій '
#               'перший ПЧАРБ [[Індія]]. За повідомленнями, у 2012—2015 роках '
#               'підводний човен оснащений балістичними ракетами збудувала '
#               '[[Північна Корея]]<ref name="topwar2">{{cite web\n'
#               ' |url         = '
#               'https://topwar.ru/37446-mir-plarb-chast-2-ya.html\n'
#               ' |title       = Мир ПЛАРБ. Часть 2-я\n'
#               ' |last        = Сергей Линник\n'
#               ' |first       = \n'
#               ' |date        = 18 декабря 2013\n'
#               ' |website     = \n'
#               ' |publisher   = «Военное обозрение»\n'
#               ' |accessdate  = 20 грудня 2018\n'
#               ' |ref         = Мир ПЛАРБ. ч. 2\n'
#               ' |archiveurl  = '
#               'https://web.archive.org/web/20181219230417/https://topwar.ru/37446-mir-plarb-chast-2-ya.html\n'
#               ' |archivedate = 19 грудень 2018\n'
#               ' |deadurl     = no\n'
#               '}} {{ref-ru}}</ref>.\n'
#               '\n'
#               'Відповідно до [[Стандарти НАТО|стандарту НАТО]] STANAG 1166 '
#               "класифікуються як ''SSBN'' ({{lang-en|Ship Submersible, "
#               'Ballistic missile, Nuclear powered}})<ref>{{cite web '
#               '|url=http://doni.daps.dla.mil/Directives/05000%20General%20Management%20Security%20and%20Safety%20Services/05-00%20General%20Admin%20and%20Management%20Su'}

# %% [markdown]
# ### meta.json file
# This file contains visual features of all articles images as well as some image metadata such as: description from Commons dataset, caption from the article, title, url and filename. For further details, please refer to [Kaggle Dataset Page](https://www.kaggle.com/jacksoncrow/extended-wikipedia-multimodal-dataset)

# %%
import json
import pprint

meta_path = out_dir + "Атомний_підводний_човен_з_балістичними_ракетами" + "/img/meta.json"
pp = pprint.PrettyPrinter(indent=2)
data = None
with open(meta_path) as json_file:
    data = json.loads(json.load(json_file))['img_meta']

print_data = data
for i in range(len(print_data)):
    if 'features' in print_data[i]:
        print_data[i]['features'] = print_data[i]['features'][:10]
print_data = {i:x for i,x in enumerate(print_data)}

pp.pprint(print_data)
# Out:
# { 0: { 'caption': 'Радянські важкі атомні ракетні підводні крейсери проєкту '
#                   '941, відомі як «Акули»,\xa0— найбільші в світі підводні '
#                   'човни',
#        'description': 'English: A starboard quarter view of a Soviet Project '
#                       '941 "Akula" class (NATO reporting name: "Typhoon") '
#                       'ballistic missile submarine underway.',
#        'features': [ '8.060253',
#                      '3.4860282',
#                      '7.7391806',
#                      '18.305214',
#                      '3.4404202',
#                      '7.2627435',
#                      '8.140114',
#                      '3.7799273',
#                      '16.627892',
#                      '2.8433392'],
#        'filename': '05adc5f7010870f755bb9390121bc9ab.jpg',
#        'title': 'Akula (Typhoon) class submarine DD-ST-85-06625.jpg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AAkula_%28Typhoon%29_class_submarine_DD-ST-85-06625.jpg'},
#   1: { 'caption': 'Очікуваний зовнішній вигляд перспективної ПЧАРБ типу '
#                   '«Колумбія» ВМС США',
#        'description': 'English: An artist rendering of the future U.S. Navy '
#                       'Columbia-class ballistic missile submarines. The 12 '
#                       'submarines of the Columbia-class will replace the '
#                       'Ohio-class submarines which are reaching their maximum '
#                       'extended service life. It is planned that the '
#                       'construction of USS Columbia (SSBN-826) will begin in '
#                       'in fiscal year 2021, with delivery in fiscal year 2028, '
#                       'and being on patrol in 2031.',
#        'features': [ '11.445309',
#                      '1.9639617',
#                      '3.493774',
#                      '10.792442',
#                      '1.0552578',
#                      '10.765967',
#                      '12.933429',
#                      '13.30743',
#                      '7.794039',
#                      '6.3429127'],
#        'filename': 'e900d459e961c829d912b4e4e18dff60.jpg',
#        'title': 'Artist rendering of a Columbia-class ballistic missile '
#                 'submarine, 2019 (190306-N-N0101-125).jpg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AArtist_rendering_of_a_Columbia-class_ballistic_missile_submarine%2C_2019_%28190306-N-N0101-125%29.jpg'},
#   2: { 'caption': 'Морський старт індійської БРПЧ K-15 Sagarika. Січень 2013',
#        'description': 'English: Country’s first under-water- launched Missile '
#                       'B05 was successfully flight tested from Bay of Bengal '
#                       'off the coast of Visakhapatnam.',
#        'features': [ '0.9617009',
#                      '5.3185606',
#                      '6.130782',
#                      '5.331265',
#                      '0.42852628',
#                      '1.5908859',
#                      '6.370875',
#                      '2.6325188',
#                      '13.713793',
#                      '26.306461'],
#        'filename': '2a9208161d1986a0ed1cfe7012e7730f.jpg',
#        'title': 'B05 SLBM.jpg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AB05_SLBM.jpg'},
#   3: { 'caption': 'Радянський РПКСП проєкту 667БД побудови першої половини '
#                   '1970-х. Фото 1997 року',
#        'features': [ '3.450381',
#                      '2.2259436',
#                      '4.8877525',
#                      '7.0908256',
#                      '3.064094',
#                      '13.303574',
#                      '8.74481',
#                      '9.462694',
#                      '5.9210854',
#                      '2.439229'],
#        'filename': '2da2b51c9c3466a469a4144c4145b709.jpg',
#        'title': 'Delta-II class nuclear-powered ballistic missle submarine '
#                 '2.jpg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3ADelta-II_class_nuclear-powered_ballistic_missle_submarine_2.jpg'},
#   4: { 'caption': 'Французька ПЧАРБ «Редутабль» після списання. Фото 2005 року',
#        'description': 'Français\xa0: Le Redoutable, premier SNLE '
#                       'français.English: Le Redoutable, first ballistic '
#                       'missile submarine of the French Navy.',
#        'features': [ '2.4323924',
#                      '0.31725824',
#                      '4.2473464',
#                      '9.407627',
#                      '8.133585',
#                      '6.284108',
#                      '9.951485',
#                      '7.7966065',
#                      '2.3641505',
#                      '0.33702374'],
#        'filename': '7531d6067666dc51dc9a783bf71f074e.jpg',
#        'title': 'FS Redoutable.jpg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AFS_Redoutable.jpg'},
#   5: { 'caption': 'Північна Корея',
#        'description': "조선말: 조선민주주의인민공화국의 국기Aragonés: Bandera de Corea d'o "
#                       'Norteالعربية: علم كوريا الشماليةБългарски: Национално '
#                       'знаме на Северна Кореяবাংলা: উত্তর কোরিয়ার জাতীয় '
#                       'পতাকাবিষ্ণুপ্রিয়া মণিপুরী: ঔয়াং কোরিয়ার '
#                       'ফিরালহানབོད་ཡིག: བྱང་ཀོ་རི་ཡ། དར་ཆ།Bosanski: Zastava '
#                       'Sjeverne KorejeCatalà: Bandera de Corea del '
#                       'NordMìng-dĕ̤ng-ngṳ̄: 朝鮮民主主義人民共和國國旗Čeština: '
#                       'Severokorejská vlajkaDansk: Nordkoreas flagDeutsch: '
#                       'Flagge NordkoreasΕλληνικά: Σημαία της Βόρειας '
#                       'ΚορέαςEsperanto: Flago de Nord-KoreioEnglish: Flag of '
#                       'North KoreaEspañol: Bandera de Corea del NorteEesti: '
#                       'Põhja-Korea lippEuskara: Ipar Koreako banderaSuomi: '
#                       'Pohjois-Korean lippuFrançais\xa0: Drapeau de la Corée '
#                       'du Nord贛語: 朝鮮民主主義人民共和國國旗Galego: Bandeira de Corea do '
#                       'Norteעברית: דגל קוריאה הצפוניתHrvatski: Zastava '
#                       'Sjeverne KorejeMagyar: Észak-Korea zászlajaBahasa '
#                       'Indonesia: Bendera Korea UtaraItaliano: Bandiera della '
#                       'Corea del Nord日本語: 朝鮮民主主義人民共和国の国旗Қазақша: Koreya '
#                       'Xalıqtıq Demokratiyalıq Respublikasınıñ Memlekettik '
#                       'bayrağı / Корея Халықтық Демократиялық Республикасының '
#                       'Мемлекеттік байрағыLietuvių: Šiaurės Korėjos vėliava文言: '
#                       '朝鮮民主主義人民共和國之國旗Монгол: Хойд Солонгос төрийн далбааBahasa '
#                       'Melayu: Bendera Korea UtaraBân-lâm-gú: 朝鮮民主主義人民共和國的國旗 / '
#                       'Tiâu-sián Bîn-chú-chú-gī Jîn-bîn Kiōng-hô-kok ê '
#                       'kok-kî-áPlattdüütsch: Flagg vun NoordkoreaNederlands: '
#                       'Vlag van Noord-KoreaNorsk bokmål: Nord-Koreas '
#                       'flaggPolski: Flaga Korei PółnocnejPortuguês: Bandeira '
#                       'da Coreia do NorteRomână: Steagul Coreei de '
#                       'NordРусский: Флаг Корейской Народно-Демократической '
#                       'РеспубликиSrpskohrvatski / српскохрватски: Zastava '
#                       'Sjeverne KorejeSlovenčina: Vlajka Kórejskej '
#                       'ľudovodemokratickej republikyСрпски / srpski: Застава '
#                       'Северне Кореје / Zastava Severne KorejeSvenska: '
#                       'Nordkoreas flaggaไทย: ธงชาติเกาหลีเหนือТатарча/tatarça: '
#                       'Koreya Xalık Demokratik Cömhüriyateneñ Däwlät '
#                       'bayrağıئۇيغۇرچە / Uyghurche: شىمالىي چاۋشيەن دۆلەت '
#                       'بايرىقىУкраїнська: Прапор Північної '
#                       'КореїOʻzbekcha/ўзбекча: Koreya Xalq Demokratik '
#                       'Respublikasining Davlat bayrogʻiTiếng Việt: 國旗共和民主人民朝鮮 '
#                       '/ Quốc kỳ Cộng hòa Dân chủ Nhân dân Triều Tiên吴语: '
#                       '朝鮮民主主義人民共和國國旗粵語: 朝鮮民主主義人民共和國國旗中文（简体）\u200e: '
#                       '朝鲜民主主义人民共和国国旗中文（繁體）\u200e: 朝鮮民主主義人民共和國國旗',
#        'features': [ '0.0',
#                      '4.573415',
#                      '0.40888047',
#                      '2.3024316',
#                      '1.2615141',
#                      '0.20993978',
#                      '11.2279',
#                      '1.2538941',
#                      '6.8074217',
#                      '7.671756'],
#        'filename': '514c7536337af69b994f2d9efbbf0770.jpg',
#        'title': 'Flag of North Korea.svg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AFlag_of_North_Korea.svg'},
#   6: { 'caption': 'Китайська ПЧАРБ типу «Цзинь» з відкритими шахтними '
#                   'пусковими установками',
#        'description': 'English: CSR Report RL33153 China Naval Modernization: '
#                       'Implications for U.S. Navy Capabilities—Background and '
#                       "Issues for Congress by Ronald O'Rourke dated February "
#                       '28, 2014.Page 8 - Figure 1. Jin (Type 094) Class '
#                       'Ballistic Missile SubmarineSource: Photograph provided '
#                       'to CRS by Navy Office of Legislative Affairs, December '
#                       '2010.',
#        'features': [ '12.630762',
#                      '2.1997373',
#                      '5.0087185',
#                      '5.827004',
#                      '3.394403',
#                      '11.937833',
#                      '5.4007926',
#                      '4.932372',
#                      '2.2008076',
#                      '3.9997938'],
#        'filename': 'c5cc2717b8009743761938c7cb9846e7.jpg',
#        'title': 'Jin (Type 094) Class Ballistic Missile Submarine.JPG',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AJin_%28Type_094%29_Class_Ballistic_Missile_Submarine.JPG'},
#   7: { 'caption': 'Запуск ракет з ПЧАРБ типу «Огайо» (3D-зображення)',
#        'description': 'Ohio-class submarine launches Tomahawk Cruise missiles '
#                       '(artist concept)original image caption: '
#                       '030606-N-0000X-005 Washington, D.C. (Jun. 6, 2003) -- '
#                       'Artist concept of the SSGN conversion program. Four '
#                       'Ohio-class strategic missile submarines USS Ohio (SSBN '
#                       '726), USS Michigan (SSBN 727) USS Florida (SSBN 728), '
#                       'and USS Georgia (SSBN 729) have been selected for '
#                       'transformation into a new platform, designated SSGN or '
#                       'Tactical Trident. The SSGNs will have the capability to '
#                       'support and launch up to 154 Tomahawk missiles, a '
#                       'significant increase in capacity as compared to other '
#                       'platforms. The 22 missile tubes will also provide the '
#                       'capability to carry other payloads, such as unmanned '
#                       'underwater vehicles (UUVs), unmanned aerial vehicles '
#                       '(UAVs) and special forces equipment. This new platform '
#                       'will also have the capability to carry and support more '
#                       'than 66 Navy SEALs (Sea, Air and Land) and insert them '
#                       'clandestinely into potential conflict areas. U.S. Navy '
#                       'graphic. (RELEASED)',
#        'features': [ '1.0384533',
#                      '5.0498214',
#                      '22.159975',
#                      '6.3071985',
#                      '4.2974815',
#                      '3.1616468',
#                      '6.396223',
#                      '1.3187768',
#                      '6.0071907',
#                      '7.1924257'],
#        'filename': '63eaae09d0b97be02c9c562786db5176.jpg',
#        'title': 'Ohio-class submarine launches Tomahawk Cruise missiles '
#                 '(artist concept).jpg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AOhio-class_submarine_launches_Tomahawk_Cruise_missiles_%28artist_concept%29.jpg'},
#   8: { 'caption': '«Класичне» компонування ПЧАРБ. Схематичний план човна типу '
#                   '«Лафаєт» ВМС США.Шахтні пускові установки (ракетний відсік) '
#                   'розташовані позаду рубки, за ними\xa0— реакторний відсік',
#        'description': 'English: Scheme of SSBN 616 LafayetteРусский: '
#                       'Схема-разрез ПЛАРБ Лафайет(SSBN 616)',
#        'features': [ '5.0344415',
#                      '5.7947903',
#                      '6.207253',
#                      '0.0',
#                      '11.736514',
#                      '4.152539',
#                      '1.6172867',
#                      '3.754846',
#                      '1.8651314',
#                      '3.6836908'],
#        'filename': '3f2caf1151776c5b6f50b787b2898434.jpg',
#        'title': 'Plan of SSBN 616.png',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3APlan_of_SSBN_616.png'},
#   9: { 'caption': 'Французькі БРПЧ M45 і M51 в шахтах (поперечний розріз '
#                   'ПЧАРБ)',
#        'description': 'Français\xa0: Missiles M45 et M51 dans des coques de '
#                       'SNLE (type Redoutable, à gauche) et de SNLE-NG (type '
#                       'Triomphant, à droite). English: Left, Redoutable class '
#                       'SSBN with M4 missile; right, Triomphant-class SSBN with '
#                       'M45 missile and far right, M51 missile with human for '
#                       'scale. Deutsch: M45 und M51 Interkontinentalraketen in '
#                       'den Hüllen der französischen Atom-U-Boote SNLE (Typ '
#                       'Redoutable, links) und SNLE-NG (Typ Triomphant, '
#                       'rechts).',
#        'features': [ '8.638453',
#                      '2.8832526',
#                      '12.074906',
#                      '13.918487',
#                      '6.65967',
#                      '6.2583623',
#                      '7.953285',
#                      '6.6956825',
#                      '24.449669',
#                      '10.639185'],
#        'filename': '6f73ff313aabcd91766ade974258c8fb.jpg',
#        'title': 'Snle-snle-ng-svg.svg',
#        'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3ASnle-snle-ng-svg.svg'},
#   10: { 'caption': 'ПЧАРБ «Вікторіус» типу «Вангард» ВМС Великої Британії. '
#                    'Квітень 2013',
#         'description': 'English: The Trident nuclear submarine HMS Victorious '
#                        'is pictured near Faslane in Scotland. HMS Victorious '
#                        'was the second of the four ballistic missile '
#                        'submarines to emerge from the Devonshire Dock Hall in '
#                        "Barrow, where she was officially 'launched' on 29 "
#                        'September 1993. Based at Clyde Naval Base, HMS '
#                        "Victorious' is continuing the Royal Navy's proud "
#                        'record of over 40 years of uninterrupted nuclear '
#                        "deterrence, as at least one of the four 'bombers' is "
#                        'on patrol at any time.',
#         'features': [ '3.198576',
#                       '3.5335827',
#                       '4.081487',
#                       '8.7467985',
#                       '3.9274998',
#                       '4.809667',
#                       '7.111782',
#                       '6.040572',
#                       '3.5520713',
#                       '2.4176123'],
#         'filename': '67a952beff05c2f80258960d4b986821.jpg',
#         'title': 'Trident Nuclear Submarine HMS Victorious.jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3ATrident_Nuclear_Submarine_HMS_Victorious.jpg'},
#   11: { 'caption': 'Пуск БРПЧ «Трайдент-II» ПЧАРБ «Західна Вірджинія» ВМС США, '
#                    '2 червня 2014',
#         'description': 'English: A UGM-133A Trident II ballistic missile is '
#                        'launched from the U.S. Navy Ohio-class ballistic '
#                        'missile submarine USS West Virginia (SSBN-736) during '
#                        'a missile test at the Atlantic Missile Range. The test '
#                        'flights were part of a demonstration and shakedown '
#                        'operation, which the U.S. Navy used to certify a '
#                        'submarine for deployment after a major overhaul. The '
#                        'missiles were converted into test configurations with '
#                        'kits containing range safety devices and flight '
#                        'telemetry instrumentation.',
#         'features': [ '2.281237',
#                       '3.6413784',
#                       '16.364756',
#                       '17.03331',
#                       '0.5166762',
#                       '8.23921',
#                       '10.244196',
#                       '3.18021',
#                       '9.951162',
#                       '35.302444'],
#         'filename': '99addf0249299f0b9896929b8effb1b7.jpg',
#         'title': 'UGM-133A Trident II launch in June 2014.JPG',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AUGM-133A_Trident_II_launch_in_June_2014.JPG'},
#   12: { 'caption': 'ПЧАРБ «Джордж Вашингтон» ВМС США — перший представник '
#                    'морської складової ядерної тріади. Увійшов у склад флоту 9 '
#                    'червня 1959',
#         'description': 'English: The U.S. Navy ballistic missile submarine USS '
#                        'George Washington (SSBN-598) underway, circa in the '
#                        '1970s.',
#         'features': [ '3.988132',
#                       '6.54922',
#                       '2.3075995',
#                       '6.8876915',
#                       '0.21435732',
#                       '6.600605',
#                       '4.629577',
#                       '11.022954',
#                       '5.4425745',
#                       '1.9157884'],
#         'filename': '3346860854b82007cca57153c61a39e0.jpg',
#         'title': 'USS George Washington (SSBN-598) underway at sea, circa in '
#                  'the 1970s.jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AUSS_George_Washington_%28SSBN-598%29_underway_at_sea%2C_circa_in_the_1970s.jpg'},
#   13: { 'caption': 'ПЧАРБ «Кентуккі» типу «Огайо» ВМС США',
#         'description': 'USS Kentucky (SSBN-737)',
#         'features': [ '5.806847',
#                       '4.0779133',
#                       '5.5543327',
#                       '6.423358',
#                       '4.7606416',
#                       '6.342683',
#                       '18.413227',
#                       '13.540452',
#                       '1.1186604',
#                       '7.6537037'],
#         'filename': '08b3e2a8d5e685df095ef61035789f54.jpg',
#         'title': 'USS Kentucky (SSBN-737).jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AUSS_Kentucky_%28SSBN-737%29.jpg'},
#   14: { 'caption': 'Технічне обслуговування пускових установок ПЧАРБ «Огайо» '
#                    'ВМС США',
#         'description': 'English: ID: DN-ST-82-01336  Service Depicted: Navy A '
#                        'deck view, looking toward the bow, of the '
#                        'nuclear-powered ballistic missile submarine OHIO '
#                        '(SSBN-726) with its missile tubes opened during '
#                        'precommissioning activities. The submarine, built by '
#                        'General Dynamics Corp., carries Trident C-4 (UGM-96) '
#                        'submarinLocation: NAVAL SUBMARINE BASE, GROTON, '
#                        'CONNECTICUT (CT) UNITED STATES OF AMERICA (USA)',
#         'features': [ '7.822363',
#                       '0.7906343',
#                       '6.89493',
#                       '4.531558',
#                       '3.9326952',
#                       '7.6119137',
#                       '4.1335964',
#                       '19.329548',
#                       '22.322573',
#                       '0.75300646'],
#         'filename': '374e8ddfee606645ad7a4a437ee2e516.jpg',
#         'title': 'USS Ohio (SSBN-726) hatches.jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AUSS_Ohio_%28SSBN-726%29_hatches.jpg'},
#   15: { 'caption': 'Спуск на воду ПЧАРБ «Патрік Генрі» типу «Джордж '
#                    'Вашингтон». 22 вересня 1959',
#         'description': 'Launch of the U.S. Navy ballistic missile submarine '
#                        'USS Patrick Henry (SSBN-599) at General Dynamics '
#                        'Electric Boat,  Groton, Connecticut (USA), on 22 '
#                        'September 1959.',
#         'features': [ '3.3876867',
#                       '3.21189',
#                       '7.0876503',
#                       '4.9651732',
#                       '4.297654',
#                       '7.922429',
#                       '8.98073',
#                       '10.960714',
#                       '11.424801',
#                       '4.0113006'],
#         'filename': '97230aab7edf4dc151d387c15ac803d4.jpg',
#         'title': 'USS Patrick Henry (SSBN-599) launch 1959.jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AUSS_Patrick_Henry_%28SSBN-599%29_launch_1959.jpg'},
#   16: { 'caption': 'ПЧАРБ «Патрік Генрі» типу «Джордж Вашингтон» повертається '
#                    'з бойової служби. Екіпаж на ракетній палубі. 1960-ті',
#         'description': 'English: The U.S. Navy ballistic missile submarine USS '
#                        'Patrick Henry (SSBN-599) returning from a patrol in '
#                        'the early 1960s.',
#         'features': [ '5.172779',
#                       '2.9642706',
#                       '7.053952',
#                       '10.301087',
#                       '5.086698',
#                       '6.4460483',
#                       '16.238682',
#                       '1.8534422',
#                       '8.571405',
#                       '6.6945395'],
#         'filename': 'e941b85ba6b66ff46c6c029bf275d3c7.jpg',
#         'title': 'USS Patrick Henry (SSBN-599) underway with crew on deck.jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3AUSS_Patrick_Henry_%28SSBN-599%29_underway_with_crew_on_deck.jpg'},
#   17: { 'caption': 'Відкриті ракетні шахти на радянському РПКСП проєкту 667БДР',
#         'description': 'Русский: Ракетные шахты РПКСН К-433 проекта 667БДР '
#                        '"Кальмар".',
#         'features': [ '6.2019114',
#                       '0.26043677',
#                       '13.028076',
#                       '2.2378016',
#                       '2.129899',
#                       '9.60729',
#                       '6.454902',
#                       '4.0832224',
#                       '9.76913',
#                       '3.0463214'],
#         'filename': '1db2c53f77e484475e8512b474990c63.jpg',
#         'title': 'Ракетные шахты.jpg',
#         'url': 'https://uk.wikipedia.org/wiki/%D0%A4%D0%B0%D0%B9%D0%BB%3A%D0%A0%D0%B0%D0%BA%D0%B5%D1%82%D0%BD%D1%8B%D0%B5_%D1%88%D0%B0%D1%85%D1%82%D1%8B.jpg'}}
